# %%
#Maximum Edge of a Triangle
def next_edge(side1, side2):
    return (side1 + side2) - 1

# %%
#Test 1
next_edge(8, 10)
# Out:
# 17

# %%
#Test 2
next_edge(5, 7)
# Out:
# 11

# %%
#Test 3
next_edge(9, 2)
# Out:
# 10

# %%
#Return the Next Number from the Integer Passed
def addition(num):
    return num + 1

# %%
#Test 1
print(addition(0))
# Out:
# 1

# %%
#Test 2
print(addition(9))
# Out:
# 10

# %%
#Test 3
print(addition(-3))
# Out:
# -2

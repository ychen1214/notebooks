# %%
#Return Multiply the Two Numbers
def multiply(a, b):
    return a * b

# %%
#Test 1
multiply(230,10)
# Out:
# 2300

# %%
#Test 2
multiply(110,3)
# Out:
# 330

# %%
#Test 3
multiply(480,20)
# Out:
# 9600

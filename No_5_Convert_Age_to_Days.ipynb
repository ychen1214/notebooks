# %%
#Convert Age to Days
def calc_age(age):
    return age * 365

# %%
#Test 1
print(calc_age(65))
# Out:
# 23725

# %%
#Test 2
print(calc_age(0))
# Out:
# 0

# %%
#Test 3
print(calc_age(20))
# Out:
# 7300

# %%
#Convert Hours into Seconds
def how_many_seconds(hours):
    return hours * 3600

# %%
#Test 1
how_many_seconds(2)
# Out:
# 7200

# %%
#Test 2
how_many_seconds(10)
# Out:
# 36000

# %%
#Test 3
how_many_seconds(24)
# Out:
# 86400

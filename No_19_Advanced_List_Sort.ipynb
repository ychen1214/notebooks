# %%
#Advanced List Sort
sorted([2, 1, 2, 1], key=abs)
# Out:
# [1, 1, 2, 2]

# %%
n = 2
my_list=sorted([5, 4, 5, 5, 4, 3])
chunks = [my_list[i:i + n] for i in range(0, len(my_list), n)]

# %%
my_list=["b", "a", "b", "a", "c"]
user = {} 
chunky = []
for x in my_list:
    user[x] = user.get(x, 0) + 1
for i, x in user.items():
    list = []
    for x in range(x):        
        list.append(i)
    chunky.append(list)    
print(chunky)
# Out:
# [['b', 'b'], ['a', 'a'], ['c']]

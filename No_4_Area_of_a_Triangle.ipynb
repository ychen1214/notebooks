# %%
#Area of a Triangle
def tri_area(base, height):
    return (base * height) / 2

# %%
#Test 1
print(tri_area(3, 2))
# Out:
# 3.0

# %%
#Test 2
print(tri_area(7, 4))
# Out:
# 14.0

# %%
#Test 3
print(tri_area(10, 10.5))
# Out:
# 52.5

# %%
#Convert minutes to seconds
def convert(minutes):
    return minutes * 60

# %%
#Test 1
print(convert(5))
# Out:
# 300

# %%
#Test 2
print(convert(3))
# Out:
# 180

# %%
#Test 3
print(convert(3))
# Out:
# 180

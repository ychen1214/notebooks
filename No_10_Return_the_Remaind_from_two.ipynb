# %%
#Return the Remainder from Two Numbers
def remainder(x, y):
    return x % y

# %%
#Test 1
remainder(1, 3)
# Out:
# 1

# %%
#Test 2
remainder(3, 4)
# Out:
# 3

# %%
#Test 3
remainder(-9, 45)
# Out:
# 36

# %%
#Test 4
remainder(7, 2)
# Out:
# 1
